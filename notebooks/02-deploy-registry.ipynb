# %%
import json
import requests

# %% [markdown]
# ## Deploy the MCP Registry

# %% [markdown]
# ### Deploy Catalog Data
#
# Create additional `ConfigMap`s storing the MCP catalogs.

# %%
# !oc create cm rh-catalog-mcp --from-file registry.json=../catalogs/rh-catalog-mcp.json
# !oc create cm rh-partners-mcp --from-file registry.json=../catalogs/rh-partners-mcp.json
# !oc create cm rh-one-mcp --from-file registry.json=../catalogs/rh-one-mcp.json
# Out:
# configmap/rh-catalog-mcp created
# configmap/rh-partners-mcp created
# configmap/rh-one-mcp created

# %% [markdown]
# ### Deploy the Registry
#
# Create the registry instance populated from the catalog sources.

# %%
# !oc apply -f ../manifests/demo-registry.yaml
# !oc wait pod -l app.kubernetes.io/name=demo-registry-api --for=condition=Ready --timeout=300s
# !oc get pods
# Out:
# secret/demo-registry-db-password created
# mcpregistry.toolhive.stacklok.dev/demo-registry created
# pod/demo-registry-api-5d6bf9f84f-bgtq6 condition met
# NAME                                       READY   STATUS    RESTARTS   AGE
# cnpg-controller-manager-846579bb9d-cpkdk   1/1     Running   0          11d
# demo-db-1                                  1/1     Running   0          76s
# demo-registry-api-5d6bf9f84f-bgtq6         1/1     Running   0          11s
# toolhive-operator-8d6c5fd48-8z6kv          1/1     Running   0          113s

# %% [markdown]
# Verify the spec contains 3 `configMapRef` and one `git` registries.

# %%
# !oc get mcpregistry demo-registry -oyaml | yq '.spec.registries'
# Out:
# - configMapRef:
#     key: registry.json
#     name: rh-one-mcp
#   format: toolhive
#   name: rh-one-mcp
#   syncPolicy:
#     interval: 1h
# - configMapRef:
#     key: registry.json
#     name: rh-catalog-mcp
#   format: toolhive
#   name: rh-catalog-mcp
#   syncPolicy:
#     interval: 1h
# - configMapRef:
#     key: registry.json
#     name: rh-partners-mcp
#   format: toolhive
#   name: rh-partners-mcp
#   syncPolicy:
#     interval: 1h
# - filter:
#     tags:
#       exclude:
#         - experimental
#       include:
#         - database
#         - filesystem
#         - api
#   format: toolhive
#   git:
#     branch: main
#     path: pkg/registry/data/registry.json
#     repository: https://github.com/stacklok/toolhive
#   name: toolhive
#   syncPolicy:
#     interval: 1h

# %% [markdown]
# Verify the exposed service.

# %%
# !oc get svc -l app.kubernetes.io/component=registry-api
# Out:
# NAME                TYPE        CLUSTER-IP      EXTERNAL-IP   PORT(S)    AGE
# demo-registry-api   ClusterIP   172.30.86.117   <none>        8080/TCP   24s

# %% [markdown]
# ## Validating the Registries
#
# **Prerequisite**: Expose the registry API service at port 8888.
#
# ```bash
# oc port-forward svc/demo-registry-api 8888:8080
# ```

# %%
REGISTRY_API_SVC_HOST = "localhost"
REGISTRY_API_SVC_PORT = 8888
REGISTRY_PATH = "registry"
EXTENSIONS_PATH = "extension"

# %%
# Build the URL to query a given registry for a given path
# If `registry` is `None` or empty, the aggregated registry will be used
def registry_api_url(registry: str, path: str):
    if registry is None or registry == "":
        return f"http://{REGISTRY_API_SVC_HOST}:{REGISTRY_API_SVC_PORT}/{REGISTRY_PATH}/v0.1/{path}"
    return f"http://{REGISTRY_API_SVC_HOST}:{REGISTRY_API_SVC_PORT}/{REGISTRY_PATH}/{registry}/v0.1/{path}"


# Get the list of MCP servers
def get_mcp_servers(registry: str = None):
    """Get the list of MCP servers from the registry API"""
    url = registry_api_url(registry, "servers")
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching servers: {e}")
        raise


# Build the URL to query an extension endpoint for a given registry
# If `registry` is `None` or empty, the aggregated registry will be used
def extension_api_url(registry: str, path: str):
    if registry is None or registry == "":
        return f"http://{REGISTRY_API_SVC_HOST}:{REGISTRY_API_SVC_PORT}/{EXTENSIONS_PATH}/v0/{path}"
    return f"http://{REGISTRY_API_SVC_HOST}:{REGISTRY_API_SVC_PORT}/{EXTENSIONS_PATH}/{registry}/v0/{path}"


# Get the list of MCP registries
def get_mcp_registries():
    """Get the list of MCP registries from the extension API"""
    url = extension_api_url(None, "registries")
    print(url)
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching registries: {e}")
        raise

# %%
# Print simple card list of the given servers
def print_server_cards(servers_list):
    """Print servers in a card layout format"""

    for idx, server_item in enumerate(servers_list, 1):
        server = server_item["server"]
        name = server.get("name", "N/A")

        # Extract package information (assuming first package)
        package = server.get("packages", [{}])[0] if server.get("packages") else {}
        registry_type = package.get("registryType", "N/A")
        identifier = package.get("identifier", "N/A")
        transport = package.get("transport", {}).get("type", "N/A")

        # Print card
        print(f"{'=' * 80}")
        print(f"Server #{idx}")
        print(f"{'-' * 80}")
        print(f"Name:       {name}")
        print(f"Transport:  {transport}")
        print(f"Registry:   {registry_type}")
        print(f"Identifier: {identifier}")

# %%
# Print global servers
servers = get_mcp_servers()["servers"]
print_server_cards(servers)
# Out:
# ================================================================================
# Server #1
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/agentops-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/agentops-mcp
# ================================================================================
# Server #2
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/agentql-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/agentql-mcp
# ================================================================================
# Server #3
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/alation-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/alation-ai-agent-sdk
# ================================================================================
# Server #4
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/alibaba-cloud-ops-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/alibaba-cloud-ops-mcp-server
# ================================================================================
# Server #5
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/alpaca-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/alpaca-mcp-server
# ================================================================================
# Server #6
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-aurora-dsql-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aurora-dsql-mcp-server
# ================================================================================
# Server #7
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-aurora-mysql-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/mysql-mcp-server
# ================================================================================
# Server #8
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-aurora-postgresql-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/postgres-mcp-server
# ================================================================================
# Server #9
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-bedrock-data-automation-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aws-bedrock-data-automation-mcp-server
# ================================================================================
# Server #10
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-bedrock-knowledge-bases-retrieval-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/bedrock-kb-retrieval-mcp-server
# ================================================================================
# Server #11
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-cloudwatch-logs-mcp-server-deprecated
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/cloudwatch-logs-mcp-server
# ================================================================================
# Server #12
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-cloudwatch-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/cloudwatch-mcp-server
# ================================================================================
# Server #13
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-documentdb-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/documentdb-mcp-server
# ================================================================================
# Server #14
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-dynamodb-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/dynamodb-mcp-server
# ================================================================================
# Server #15
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-ecs-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/ecs-mcp-server
# ================================================================================
# Server #16
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-eks-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/eks-mcp-server
# ================================================================================
# Server #17
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-elasticache-for-memcached-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/memcached-mcp-server
# ================================================================================
# Server #18
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-elasticache-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/elasticache-mcp-server
# ================================================================================
# Server #19
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-elasticache-memorydb-for-valkey-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/valkey-mcp-server
# ================================================================================
# Server #20
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-kendra-index-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-kendra-index-mcp-server
# ================================================================================
# Server #21
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-keyspaces-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-keyspaces-mcp-server
# ================================================================================
# Server #22
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-location-service-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aws-location-mcp-server
# ================================================================================
# Server #23
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-mq-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-mq-mcp-server
# ================================================================================
# Server #24
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-msk-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aws-msk-mcp-server
# ================================================================================
# Server #25
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-neptune-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-neptune-mcp-server
# ================================================================================
# Server #26
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-nova-canvas-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/nova-canvas-mcp-server
# ================================================================================
# Server #27
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-q-business-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-qbusiness-anonymous-mcp-server
# ================================================================================
# Server #28
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-q-index-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-qindex-mcp-server
# ================================================================================
# Server #29
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-redshift-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/redshift-mcp-server
# ================================================================================
# Server #30
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-rekognition-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-rekognition-mcp-server
# ================================================================================
# Server #31
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-sns-sqs-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/amazon-sns-sqs-mcp-server
# ================================================================================
# Server #32
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/amazon-timestream-influxdb-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/timestream-for-influxdb-mcp-server
# ================================================================================
# Server #33
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/ant-intl-alipayplus-mcp
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/global-alipayplus-mcp
# ================================================================================
# Server #34
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/ant-intl-antom-mcp
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/global-antom-mcp
# ================================================================================
# Server #35
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/apify-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/apify-mcp-server
# ================================================================================
# Server #36
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/armor-crypto-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/armor-crypto-mcp
# ================================================================================
# Server #37
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/astra-db-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/astra-db-mcp
# ================================================================================
# Server #38
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/atlan-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/modelcontextprotocol
# ================================================================================
# Server #39
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/audiense-insights-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/mcp-audiense-insights
# ================================================================================
# Server #40
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/authenticator-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/authenticator_mcp
# ================================================================================
# Server #41
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-cdk-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/cdk-mcp-server
# ================================================================================
# Server #42
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-cloud-control-api-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/ccapi-mcp-server
# ================================================================================
# Server #43
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-cloudformation-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/cfn-mcp-server
# ================================================================================
# Server #44
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-cost-explorer-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/cost-explorer-mcp-server
# ================================================================================
# Server #45
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-data-processing-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aws-dataprocessing-mcp-server
# ================================================================================
# Server #46
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-diagram-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aws-diagram-mcp-server
# ================================================================================
# Server #47
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-documentation-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aws-documentation-mcp-server
# ================================================================================
# Server #48
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-healthlake-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/healthlake-mcp-server
# ================================================================================
# Server #49
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-healthomics-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/aws-healthomics-mcp-server
# ================================================================================
# Server #50
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/aws-iam-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/awslabs/iam-mcp-server

# %%
# Print first 3 servers for each registry
registries = get_mcp_registries()
for registry in registries["registries"]:
    registryName = registry["name"]

    print(f"{'*' * 80}")
    print(f"Registry: {registryName} [{registry['sourceType']}]")
    print(f"{'*' * 80}")
    servers = get_mcp_servers(registryName)["servers"]
    print_server_cards(servers[:3])
# Out:
# http://localhost:8888/extension/v0/registries
# ********************************************************************************
# Registry: default [kubernetes]
# ********************************************************************************
# ********************************************************************************
# Registry: rh-catalog-mcp [file]
# ********************************************************************************
# ================================================================================
# Server #1
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/agentops-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/agentops-mcp
# ================================================================================
# Server #2
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/agentql-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/agentql-mcp
# ================================================================================
# Server #3
# --------------------------------------------------------------------------------
# Name:       io.github.stacklok/alation-mcp-server
# Transport:  stdio
# Registry:   oci
# Identifier: quay.io/mcp-servers/alation-ai-agent-sdk
# ********************************************************************************
# Registry: rh-one-mcp [file]
# ********************************************************************************
# ********************************************************************************
# Registry: rh-partners-mcp [file]
# ********************************************************************************
# ********************************************************************************
# Registry: toolhive [git]
# ********************************************************************************

# %% [markdown]
# ## Conclusion
#
# We successfully deployed and validated the MCP Registry on OpenShift:
#
# - ✅ Created 3 `ConfigMap`-based catalog sources (`rh-catalog-mcp`, `rh-partners-mcp`, `rh-one-mcp`)
# - ✅ Deployed the `demo-registry` instance aggregating 4 registries (3 `ConfigMap`s + 1 Git-based)
# - ✅ Verified the registry API service is accessible and functioning correctly
# - ✅ Validated server discovery across multiple registry sources
#
# The MCP Registry is now ready for discovering and deploying MCP servers. Proceed to the next notebook to deploy and discover MCP servers using this registry.
